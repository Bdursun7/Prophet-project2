# %%
# !pip install numpy==1.24.3

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from prophet import Prophet
from sklearn.metrics import mean_squared_error, mean_absolute_error
from google.colab import drive
drive.mount('/content/drive')
plt.style.use('fivethirtyeight') # For plots
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/Prophet Project/PJME_hourly.csv") # We set the index column and know it has dates

# %%
data
# Out:
#                    Datetime  PJME_MW
# 0       2002-12-31 01:00:00  26498.0
# 1       2002-12-31 02:00:00  25147.0
# 2       2002-12-31 03:00:00  24574.0
# 3       2002-12-31 04:00:00  24393.0
# 4       2002-12-31 05:00:00  24860.0
# ...                     ...      ...
# 145361  2018-01-01 20:00:00  44284.0
# 145362  2018-01-01 21:00:00  43751.0
# 145363  2018-01-01 22:00:00  42402.0
# 145364  2018-01-01 23:00:00  40164.0
# 145365  2018-01-02 00:00:00  38608.0
#
# [145366 rows x 2 columns]

# %%
df = data.copy()

# %%
df
# Out:
#                    Datetime  PJME_MW
# 0       2002-12-31 01:00:00  26498.0
# 1       2002-12-31 02:00:00  25147.0
# 2       2002-12-31 03:00:00  24574.0
# 3       2002-12-31 04:00:00  24393.0
# 4       2002-12-31 05:00:00  24860.0
# ...                     ...      ...
# 145361  2018-01-01 20:00:00  44284.0
# 145362  2018-01-01 21:00:00  43751.0
# 145363  2018-01-01 22:00:00  42402.0
# 145364  2018-01-01 23:00:00  40164.0
# 145365  2018-01-02 00:00:00  38608.0
#
# [145366 rows x 2 columns]

# %%
df.describe()
# Out:
#              PJME_MW
# count  145366.000000
# mean    32080.222831
# std      6464.012166
# min     14544.000000
# 25%     27573.000000
# 50%     31421.000000
# 75%     35650.000000
# max     62009.000000

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'])

# Grafiği çizdirme
plt.figure(figsize=(15, 5))
plt.plot(df['Datetime'], df['PJME_MW'], color='purple')
plt.title('PJM East Enerji Tüketimi')
plt.xlabel('Tarih')
plt.ylabel('Enerji Tüketimi (MW)')
plt.grid(True)
plt.show()

# %%
df.isnull().sum()
# Out:
# Datetime    0
# PJME_MW     0
# dtype: int64

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'])

# %%
def create_features(df, label=None):
    """
    Creates time series features from datetime index.
    """
    df = df.copy()
    df['Datetime'] = pd.to_datetime(df.index)  # Convert the index to Pandas DatetimeIndex

    df['hour'] = df['Datetime'].dt.hour
    df['dayofweek'] = df['Datetime'].dt.dayofweek
    df['quarter'] = df['Datetime'].dt.quarter
    df['month'] = df['Datetime'].dt.month
    df['year'] = df['Datetime'].dt.year
    df['dayofyear'] = df['Datetime'].dt.dayofyear
    df['dayofmonth'] = df['Datetime'].dt.day
    df['weekofyear'] = df['Datetime'].dt.isocalendar().week  # Use isocalendar to get the week of the year

    X = df[['hour','dayofweek','quarter','month','year',
           'dayofyear','dayofmonth','weekofyear']]
    if label:
        y = df[label]
        return X, y
    return X

X, y = create_features(df, label='PJME_MW')

features_and_target = pd.concat([X, y], axis=1)

# %%
features_and_target.head()
# Out:
#    hour  dayofweek  quarter  month  year  dayofyear  dayofmonth  weekofyear  \
# 0     0          3        1      1  1970          1           1           1
# 1     0          3        1      1  1970          1           1           1
# 2     0          3        1      1  1970          1           1           1
# 3     0          3        1      1  1970          1           1           1
# 4     0          3        1      1  1970          1           1           1
#
#    PJME_MW
# 0  26498.0
# 1  25147.0
# 2  24574.0
# 3  24393.0
# 4  24860.0

# %%
sns.pairplot(features_and_target.dropna(),
             hue='hour',
             x_vars=['hour','dayofweek',
                     'year','weekofyear'],
             y_vars='PJME_MW',
             height=5,
             plot_kws={'alpha':0.15, 'linewidth':0}
            )
plt.suptitle('Power Use MW by Hour, Day of Week, Year and Week of Year')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df
# Out:
#                   Datetime  PJME_MW
# 0      2002-12-31 01:00:00  26498.0
# 1      2002-12-31 02:00:00  25147.0
# 2      2002-12-31 03:00:00  24574.0
# 3      2002-12-31 04:00:00  24393.0
# 4      2002-12-31 05:00:00  24860.0
# ...                    ...      ...
# 145361 2018-01-01 20:00:00  44284.0
# 145362 2018-01-01 21:00:00  43751.0
# 145363 2018-01-01 22:00:00  42402.0
# 145364 2018-01-01 23:00:00  40164.0
# 145365 2018-01-02 00:00:00  38608.0
#
# [145366 rows x 2 columns]

# %%
train_size = int(len(df) * 0.80)  # %80'i train, %20'si test verisi olarak kullanalım
train_df = df[:train_size]
test_df = df[train_size:]
train_df = train_df.rename(columns={'Datetime': 'ds', 'PJME_MW': 'y'})
test_df = test_df.rename(columns={'Datetime': 'ds', 'PJME_MW': 'y'})

# %%
train_df
# Out:
#                         ds        y
# 0      2002-12-31 01:00:00  26498.0
# 1      2002-12-31 02:00:00  25147.0
# 2      2002-12-31 03:00:00  24574.0
# 3      2002-12-31 04:00:00  24393.0
# 4      2002-12-31 05:00:00  24860.0
# ...                    ...      ...
# 116287 2015-09-24 08:00:00  27884.0
# 116288 2015-09-24 09:00:00  28777.0
# 116289 2015-09-24 10:00:00  29610.0
# 116290 2015-09-24 11:00:00  30504.0
# 116291 2015-09-24 12:00:00  31265.0
#
# [116292 rows x 2 columns]

# %%
test_df
# Out:
#                         ds        y
# 116292 2015-09-24 13:00:00  32002.0
# 116293 2015-09-24 14:00:00  32634.0
# 116294 2015-09-24 15:00:00  33251.0
# 116295 2015-09-24 16:00:00  33741.0
# 116296 2015-09-24 17:00:00  34230.0
# ...                    ...      ...
# 145361 2018-01-01 20:00:00  44284.0
# 145362 2018-01-01 21:00:00  43751.0
# 145363 2018-01-01 22:00:00  42402.0
# 145364 2018-01-01 23:00:00  40164.0
# 145365 2018-01-02 00:00:00  38608.0
#
# [29074 rows x 2 columns]

# %%
# Plotting the train and test data
plt.figure(figsize=(13, 5))

# Train data in blue color with 'o' marker
plt.scatter(train_df['ds'], train_df['y'], color='red', marker='o', label='Train Data')

# Test data in red color with 'x' marker
plt.scatter(test_df['ds'], test_df['y'], color='blue', marker='x', label='Test Data')

plt.xlabel('Datetime')
plt.ylabel('PJME_MW')
plt.title('Train and Test Data Split')
plt.legend()
plt.grid(True)
plt.show()

# %%
model= Prophet()

# %%
model.fit(train_df)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8xnd1fdk/udgepo_c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8xnd1fdk/6iivkreq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5187', 'data', 'file=/tmp/tmp8xnd1fdk/udgepo_c.json', 'init=/tmp/tmp8xnd1fdk/6iivkreq.json', 'output', 'file=/tmp/tmp8xnd1fdk/prophet_modelka4r5gas/prophet_model-20230803112147.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:21:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:23:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecast = model.predict(test_df)

# %%
# Tahmin sonuçlarını görselleştirme
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(test_df['ds'], test_df['y'], label='Gerçek Veri')  # Gerçek verileri çizdirme
ax.plot(forecast['ds'], forecast['yhat'], label='Tahmin', color='red')  # Tahminleri çizdirme
ax.fill_between(forecast['ds'], forecast['yhat_lower'], forecast['yhat_upper'], color='pink', alpha=0.2)  # Belirsizlik aralığını çizdirme
plt.legend()
plt.xlabel('Tarih')
plt.ylabel('Enerji Tüketimi')
plt.title('Enerji Tüketimi Tahmini')
plt.show()

# %%
from sklearn.metrics import r2_score

# R-kare değerini hesaplama
r2 = r2_score(test_df['y'], forecast['yhat'])

print("R-kare değeri:", r2)
# Out:
# R-kare değeri: -0.27519821034877023

# %%
# Tahmin sonuçlarını görselleştirme
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(test_df['ds'], test_df['y'], label='Gerçek Veri')  # Gerçek verileri çizdirme
#ax.plot(forecast['ds'], forecast['yhat'], label='Tahmin', color='red')  # Tahminleri çizdirme
#ax.fill_between(forecast['ds'], forecast['yhat_lower'], forecast['yhat_upper'], color='pink', alpha=0.2)  # Belirsizlik aralığını çizdirme
plt.legend()
plt.xlabel('Tarih')
plt.ylabel('Enerji Tüketimi')
plt.title('Enerji Tüketimi Tahmini')
plt.show()

# %%
test_df
#Datamızdaki sıralamada bir hata olduğunu ondan dolayı grafiklerimizde atlamalar olduğunu gördük datayı düzenlemeye tekrar dönmemiz lazım
# Out:
#                         ds        y
# 116292 2015-09-24 13:00:00  32002.0
# 116293 2015-09-24 14:00:00  32634.0
# 116294 2015-09-24 15:00:00  33251.0
# 116295 2015-09-24 16:00:00  33741.0
# 116296 2015-09-24 17:00:00  34230.0
# ...                    ...      ...
# 145361 2018-01-01 20:00:00  44284.0
# 145362 2018-01-01 21:00:00  43751.0
# 145363 2018-01-01 22:00:00  42402.0
# 145364 2018-01-01 23:00:00  40164.0
# 145365 2018-01-02 00:00:00  38608.0
#
# [29074 rows x 2 columns]

# %%
df
# Out:
#                   Datetime  PJME_MW
# 0      2002-12-31 01:00:00  26498.0
# 1      2002-12-31 02:00:00  25147.0
# 2      2002-12-31 03:00:00  24574.0
# 3      2002-12-31 04:00:00  24393.0
# 4      2002-12-31 05:00:00  24860.0
# ...                    ...      ...
# 145361 2018-01-01 20:00:00  44284.0
# 145362 2018-01-01 21:00:00  43751.0
# 145363 2018-01-01 22:00:00  42402.0
# 145364 2018-01-01 23:00:00  40164.0
# 145365 2018-01-02 00:00:00  38608.0
#
# [145366 rows x 2 columns]

# %%
# 'Tarih_Saat' sütununu 'Timestamp' nesnelerine dönüştürme
df['Datetime'] = pd.to_datetime(df['Datetime'])

# 'Tarih_Saat' sütununa göre kronolojik olarak veriyi sıralama
df_sorted = df.sort_values(by='Datetime')

# %%
df_sorted
# Out:
#                   Datetime  PJME_MW
# 8734   2002-01-01 01:00:00  30393.0
# 8735   2002-01-01 02:00:00  29265.0
# 8736   2002-01-01 03:00:00  28357.0
# 8737   2002-01-01 04:00:00  27899.0
# 8738   2002-01-01 05:00:00  28057.0
# ...                    ...      ...
# 140250 2018-08-02 20:00:00  44057.0
# 140251 2018-08-02 21:00:00  43256.0
# 140252 2018-08-02 22:00:00  41552.0
# 140253 2018-08-02 23:00:00  38500.0
# 140254 2018-08-03 00:00:00  35486.0
#
# [145366 rows x 2 columns]

# %%
# Tahmin sonuçlarını görselleştirme
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(df_sorted['Datetime'], df_sorted['PJME_MW'], label='Gerçek Veri')  # Gerçek verileri çizdirme
#ax.plot(forecast['ds'], forecast['yhat'], label='Tahmin', color='red')  # Tahminleri çizdirme
#ax.fill_between(forecast['ds'], forecast['yhat_lower'], forecast['yhat_upper'], color='pink', alpha=0.2)  # Belirsizlik aralığını çizdirme
plt.legend()
plt.xlabel('Tarih')
plt.ylabel('Enerji Tüketimi')
plt.title('Enerji Tüketimi Tahmini')
plt.show()

# %%
train_size = int(len(df_sorted) * 0.80)  # %80'i train, %20'si test verisi olarak kullanalım
train_df = df_sorted[:train_size]
test_df = df_sorted[train_size:]
train_df = train_df.rename(columns={'Datetime': 'ds', 'PJME_MW': 'y'})
test_df = test_df.rename(columns={'Datetime': 'ds', 'PJME_MW': 'y'})

# %%
model_v2 = Prophet()

# %%
model_v2.fit(train_df)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8xnd1fdk/lh4buz_v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8xnd1fdk/rpn9qu8_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47122', 'data', 'file=/tmp/tmp8xnd1fdk/lh4buz_v.json', 'init=/tmp/tmp8xnd1fdk/rpn9qu8_.json', 'output', 'file=/tmp/tmp8xnd1fdk/prophet_model6butku80/prophet_model-20230803112337.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:23:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:25:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecast_v2 = model_v2.predict(test_df)

# %%
# Tahmin sonuçlarını görselleştirme
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(test_df['ds'], test_df['y'], label='Gerçek Veri')  # Gerçek verileri çizdirme
ax.plot(forecast_v2['ds'], forecast_v2['yhat'], label='Tahmin', color='red')  # Tahminleri çizdirme
ax.fill_between(forecast_v2['ds'], forecast_v2['yhat_lower'], forecast_v2['yhat_upper'], color='pink', alpha=0.2)  # Belirsizlik aralığını çizdirme
plt.legend()
plt.xlabel('Tarih')
plt.ylabel('Enerji Tüketimi')
plt.title('Enerji Tüketimi Tahmini')
plt.show()

# %%
# R-kare değerini hesaplama
r2 = r2_score(test_df['y'], forecast_v2['yhat'])

print("R-kare değeri:", r2)
# Out:
# R-kare değeri: 0.5947537817761863

# %%
# Plot the components of the model

fig = model.plot_components(forecast_v2, figsize=(12,10))

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    """Calculates MAPE given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

print("MAPE değeri: %", mean_absolute_percentage_error(y_true=test_df['y'], y_pred=forecast_v2['yhat']))
# Out:
# MAPE değeri: % 10.617394395708272

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

cal = calendar()

# %%
df_sorted
# Out:
#                   Datetime  PJME_MW
# 8734   2002-01-01 01:00:00  30393.0
# 8735   2002-01-01 02:00:00  29265.0
# 8736   2002-01-01 03:00:00  28357.0
# 8737   2002-01-01 04:00:00  27899.0
# 8738   2002-01-01 05:00:00  28057.0
# ...                    ...      ...
# 140250 2018-08-02 20:00:00  44057.0
# 140251 2018-08-02 21:00:00  43256.0
# 140252 2018-08-02 22:00:00  41552.0
# 140253 2018-08-02 23:00:00  38500.0
# 140254 2018-08-03 00:00:00  35486.0
#
# [145366 rows x 2 columns]

# %%
# Assuming you have a DataFrame named df_sorted with 'Datetime' column
df_holiday = df_sorted.copy()
df_holiday['is_holiday'] = df_holiday['Datetime'].isin([d.date() for d in cal.holidays()])
holiday_df = df_holiday.loc[df_holiday['is_holiday']] \
    .reset_index() \
    .rename(columns={'Datetime':'ds'})
holiday_df['holiday'] = 'USFederalHoliday'
holiday_df = holiday_df.drop(['PJME_MW', 'is_holiday'], axis=1)

# Print the matched dates DataFrame
holiday_df
# Out:
#       index         ds           holiday
# 0      8301 2002-01-21  USFederalHoliday
# 1      7629 2002-02-18  USFederalHoliday
# 2      5278 2002-05-27  USFederalHoliday
# 3      4366 2002-07-04  USFederalHoliday
# 4      2926 2002-09-02  USFederalHoliday
# ..      ...        ...               ...
# 159  131494 2018-01-01  USFederalHoliday
# 160  145053 2018-01-15  USFederalHoliday
# 161  144213 2018-02-19  USFederalHoliday
# 162  141862 2018-05-28  USFederalHoliday
# 163  140974 2018-07-04  USFederalHoliday
#
# [164 rows x 3 columns]

# %%
holiday_df['ds'] = pd.to_datetime(holiday_df['ds'])

# %%
holiday_df
# Out:
#       index         ds           holiday
# 0      8301 2002-01-21  USFederalHoliday
# 1      7629 2002-02-18  USFederalHoliday
# 2      5278 2002-05-27  USFederalHoliday
# 3      4366 2002-07-04  USFederalHoliday
# 4      2926 2002-09-02  USFederalHoliday
# ..      ...        ...               ...
# 159  131494 2018-01-01  USFederalHoliday
# 160  145053 2018-01-15  USFederalHoliday
# 161  144213 2018-02-19  USFederalHoliday
# 162  141862 2018-05-28  USFederalHoliday
# 163  140974 2018-07-04  USFederalHoliday
#
# [164 rows x 3 columns]

# %%
# Setup and train model with holidays
model_with_holidays = Prophet(holidays=holiday_df)

model_with_holidays.fit(train_df.reset_index() \
                            .rename(columns={'Datetime':'ds',
                                             'PJME_MW':'y'}))
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8xnd1fdk/svxyrbpi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8xnd1fdk/5xem0yt6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90164', 'data', 'file=/tmp/tmp8xnd1fdk/svxyrbpi.json', 'init=/tmp/tmp8xnd1fdk/5xem0yt6.json', 'output', 'file=/tmp/tmp8xnd1fdk/prophet_modelhcpm1vax/prophet_model-20230803112528.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:25:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecast_with_holiday = model_with_holidays.predict(test_df.reset_index() \
                                                          .rename(columns={'Datetime':'ds',
                                                                               'PJME_MW':'y'}))

# %%
# Tahmin sonuçlarını görselleştirme
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(test_df['ds'], test_df['y'], label='Gerçek Veri')  # Gerçek verileri çizdirme
ax.plot(forecast_with_holiday['ds'], forecast_with_holiday['yhat'], label='Tahmin', color='red')  # Tahminleri çizdirme
ax.fill_between(forecast_with_holiday['ds'], forecast_with_holiday['yhat_lower'], forecast_with_holiday['yhat_upper'], color='black', alpha=0.2)  # Belirsizlik aralığını çizdirme
plt.legend()
plt.xlabel('Tarih')
plt.ylabel('Enerji Tüketimi')
plt.title('Enerji Tüketimi Tahmini')
plt.show()

# %%
# R-kare değerini hesaplama
r2 = r2_score(test_df['y'], forecast_with_holiday['yhat'])

print("R-kare değeri:", r2)
# Out:
# R-kare değeri: 0.5941630677614207

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    """Calculates MAPE given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

print("MAPE değeri: %", mean_absolute_percentage_error(y_true=test_df['y'], y_pred=forecast_with_holiday['yhat']))
# Out:
# MAPE değeri: % 10.669715577112527

# %%
train_df
# Out:
#                         ds        y
# 8734   2002-01-01 01:00:00  30393.0
# 8735   2002-01-01 02:00:00  29265.0
# 8736   2002-01-01 03:00:00  28357.0
# 8737   2002-01-01 04:00:00  27899.0
# 8738   2002-01-01 05:00:00  28057.0
# ...                    ...      ...
# 120321 2015-04-09 10:00:00  33082.0
# 120322 2015-04-09 11:00:00  33285.0
# 120323 2015-04-09 12:00:00  33148.0
# 120324 2015-04-09 13:00:00  32809.0
# 120325 2015-04-09 14:00:00  32613.0
#
# [116292 rows x 2 columns]

# %%
# Clean Data
train_df['y_clean'] = train_df['y']
train_df.loc[train_df['y'] < 19000, 'y_clean'] = np.nan

# %%
train_df
# Out:
#                         ds        y  y_clean
# 8734   2002-01-01 01:00:00  30393.0  30393.0
# 8735   2002-01-01 02:00:00  29265.0  29265.0
# 8736   2002-01-01 03:00:00  28357.0  28357.0
# 8737   2002-01-01 04:00:00  27899.0  27899.0
# 8738   2002-01-01 05:00:00  28057.0  28057.0
# ...                    ...      ...      ...
# 120321 2015-04-09 10:00:00  33082.0  33082.0
# 120322 2015-04-09 11:00:00  33285.0  33285.0
# 120323 2015-04-09 12:00:00  33148.0  33148.0
# 120324 2015-04-09 13:00:00  32809.0  32809.0
# 120325 2015-04-09 14:00:00  32613.0  32613.0
#
# [116292 rows x 3 columns]

# %%
train_df = train_df.drop(columns="y")

# %%
train_df.isnull().sum()
# Out:
# ds          0
# y_clean    15
# dtype: int64

# %%
train_df.dropna(subset=['y_clean'], inplace=True)

# %%
train_df.isnull().sum()
# Out:
# ds         0
# y_clean    0
# dtype: int64

# %%
train_df.rename(columns={'y_clean': 'y'}, inplace=True)

# %%
train_df
# Out:
#                         ds        y
# 8734   2002-01-01 01:00:00  30393.0
# 8735   2002-01-01 02:00:00  29265.0
# 8736   2002-01-01 03:00:00  28357.0
# 8737   2002-01-01 04:00:00  27899.0
# 8738   2002-01-01 05:00:00  28057.0
# ...                    ...      ...
# 120321 2015-04-09 10:00:00  33082.0
# 120322 2015-04-09 11:00:00  33285.0
# 120323 2015-04-09 12:00:00  33148.0
# 120324 2015-04-09 13:00:00  32809.0
# 120325 2015-04-09 14:00:00  32613.0
#
# [116277 rows x 2 columns]

# %%
# Clean Data
test_df['y_clean'] = test_df['y']
test_df.loc[test_df['y'] < 19000, 'y_clean'] = np.nan

# %%
test_df = test_df.drop(columns="y")

# %%
test_df.isnull().sum()
# Out:
# ds         0
# y_clean    0
# dtype: int64

# %%
test_df
# Out:
#                         ds  y_clean
# 120326 2015-04-09 15:00:00  32204.0
# 120327 2015-04-09 16:00:00  32049.0
# 120328 2015-04-09 17:00:00  32209.0
# 120329 2015-04-09 18:00:00  32707.0
# 120330 2015-04-09 19:00:00  33012.0
# ...                    ...      ...
# 140250 2018-08-02 20:00:00  44057.0
# 140251 2018-08-02 21:00:00  43256.0
# 140252 2018-08-02 22:00:00  41552.0
# 140253 2018-08-02 23:00:00  38500.0
# 140254 2018-08-03 00:00:00  35486.0
#
# [29074 rows x 2 columns]

# %%
test_df.rename(columns={'y_clean': 'y'}, inplace=True)

# %%
test_df
# Out:
#                         ds        y
# 120326 2015-04-09 15:00:00  32204.0
# 120327 2015-04-09 16:00:00  32049.0
# 120328 2015-04-09 17:00:00  32209.0
# 120329 2015-04-09 18:00:00  32707.0
# 120330 2015-04-09 19:00:00  33012.0
# ...                    ...      ...
# 140250 2018-08-02 20:00:00  44057.0
# 140251 2018-08-02 21:00:00  43256.0
# 140252 2018-08-02 22:00:00  41552.0
# 140253 2018-08-02 23:00:00  38500.0
# 140254 2018-08-03 00:00:00  35486.0
#
# [29074 rows x 2 columns]

# %%
# Setup and train model with holidays
fixed_model = Prophet()

fixed_model.fit(train_df)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8xnd1fdk/lobzht1k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8xnd1fdk/q214_l86.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5594', 'data', 'file=/tmp/tmp8xnd1fdk/lobzht1k.json', 'init=/tmp/tmp8xnd1fdk/q214_l86.json', 'output', 'file=/tmp/tmp8xnd1fdk/prophet_modelbwm5n_13/prophet_model-20230803112701.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:27:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:28:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecast_with_fixed_model = fixed_model.predict(test_df)

# %%
# Tahmin sonuçlarını görselleştirme
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(test_df['ds'], test_df['y'], label='Gerçek Veri')  # Gerçek verileri çizdirme
ax.plot(forecast_with_fixed_model['ds'], forecast_with_fixed_model['yhat'], label='Tahmin', color='red')  # Tahminleri çizdirme
ax.fill_between(forecast_with_fixed_model['ds'], forecast_with_fixed_model['yhat_lower'], forecast_with_fixed_model['yhat_upper'], color='black', alpha=0.2)  # Belirsizlik aralığını çizdirme
plt.legend()
plt.xlabel('Tarih')
plt.ylabel('Enerji Tüketimi')
plt.title('Enerji Tüketimi Tahmini')
plt.show()

# %%
# R-kare değerini hesaplama
r2 = r2_score(test_df['y'], forecast_with_fixed_model['yhat'])

print("R-kare değeri:", r2)
# Out:
# R-kare değeri: 0.593986850561016

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    """Calculates MAPE given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

print("MAPE değeri: %", mean_absolute_percentage_error(y_true=test_df['y'], y_pred=forecast_with_fixed_model['yhat']))
# Out:
# MAPE değeri: % 10.642585689329078

# %%
# Setup and train model with holidays
fixed_model_with_holiday = Prophet(holidays=holiday_df)

fixed_model_with_holiday.fit(train_df)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8xnd1fdk/yv36u264.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8xnd1fdk/mcfl2nh4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54808', 'data', 'file=/tmp/tmp8xnd1fdk/yv36u264.json', 'init=/tmp/tmp8xnd1fdk/mcfl2nh4.json', 'output', 'file=/tmp/tmp8xnd1fdk/prophet_modelpax2vutr/prophet_model-20230803112839.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:28:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:30:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecast_with_fixed_model_holiday = fixed_model_with_holiday.predict(test_df)

# %%
# Tahmin sonuçlarını görselleştirme
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(test_df['ds'], test_df['y'], label='Gerçek Veri')  # Gerçek verileri çizdirme
ax.plot(forecast_with_fixed_model_holiday['ds'], forecast_with_fixed_model_holiday['yhat'], label='Tahmin', color='red')  # Tahminleri çizdirme
ax.fill_between(forecast_with_fixed_model_holiday['ds'], forecast_with_fixed_model_holiday['yhat_lower'], forecast_with_fixed_model_holiday['yhat_upper'], color='black', alpha=0.2)  # Belirsizlik aralığını çizdirme
plt.legend()
plt.xlabel('Tarih')
plt.ylabel('Enerji Tüketimi')
plt.title('Enerji Tüketimi Tahmini')
plt.show()

# %%
# R-kare değerini hesaplama
r2 = r2_score(test_df['y'], forecast_with_fixed_model_holiday['yhat'])

print("R-kare değeri:", r2)
# Out:
# R-kare değeri: 0.596068204872992

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    """Calculates MAPE given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

print("MAPE değeri: %", mean_absolute_percentage_error(y_true=test_df['y'], y_pred=forecast_with_fixed_model_holiday['yhat']))
# Out:
# MAPE değeri: % 10.614961516063595

# %% [markdown]
# Forecast_v2                =>
#
#
#                                     R2 => 0.594753
#
#                                     MAPE => %10.67394
#
# Model_with_holidays        =>
#
#                                     R2 => 0.594163
#
#                                     MAPE => %10.669715
#
# Fixed_model                =>
#
#
#                                     R2 => 0.593986
#
#                                     MAPE => %10.642585
#
# Fixed_model_with_holiday   =>
#
#                                     R2 => 0.596068
#
#                                     MAPE => %10.614961

# %%
final_df = pd.concat([train_df, test_df], axis=0)

# %%
final_df
# Out:
#                         ds        y
# 8734   2002-01-01 01:00:00  30393.0
# 8735   2002-01-01 02:00:00  29265.0
# 8736   2002-01-01 03:00:00  28357.0
# 8737   2002-01-01 04:00:00  27899.0
# 8738   2002-01-01 05:00:00  28057.0
# ...                    ...      ...
# 140250 2018-08-02 20:00:00  44057.0
# 140251 2018-08-02 21:00:00  43256.0
# 140252 2018-08-02 22:00:00  41552.0
# 140253 2018-08-02 23:00:00  38500.0
# 140254 2018-08-03 00:00:00  35486.0
#
# [145351 rows x 2 columns]

# %%
# Setup and train model with holidays
Final_model = Prophet(holidays=holiday_df)

Final_model.fit(final_df)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8xnd1fdk/7t2mzfhp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8xnd1fdk/3959vru4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42810', 'data', 'file=/tmp/tmp8xnd1fdk/7t2mzfhp.json', 'init=/tmp/tmp8xnd1fdk/3959vru4.json', 'output', 'file=/tmp/tmp8xnd1fdk/prophet_modelly4dips_/prophet_model-20230803113043.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:30:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:32:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future = Final_model.make_future_dataframe(periods=100, freq='H')

# %%
forecast_final = Final_model.predict(future)

# %%
# forecast_final veri çerçevesindeki tarihleri datetime olarak ayarlayalım
forecast_final['ds'] = pd.to_datetime(forecast_final['ds'])

# 2017 yılından sonra olan tahmin sonuçlarını seçelim
forecast_after_2017 = forecast_final[forecast_final['ds'] >= '2018-07-01']
train_df2_after_2017 = final_df[final_df['ds'] >= '2018-07-01']

# Görselleştirme
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(train_df2_after_2017['ds'], train_df2_after_2017['y'], label='Gerçek Veri')  # 2017 yılından sonraki gerçek verileri çizdirme
ax.plot(forecast_after_2017['ds'], forecast_after_2017['yhat'], label='Tahmin', color='red')  # Tahminleri çizdirme
ax.fill_between(forecast_after_2017['ds'], forecast_after_2017['yhat_lower'], forecast_after_2017['yhat_upper'], color='pink', alpha=0.2)  # Belirsizlik aralığını çizdirme
plt.legend()
plt.xlabel('Tarih')
plt.ylabel('Enerji Tüketimi')
plt.title('Enerji Tüketimi Tahmini (2018-07 Sonrası)')
plt.show()
